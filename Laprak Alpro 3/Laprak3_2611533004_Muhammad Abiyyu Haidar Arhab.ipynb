# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA PEMOGRAMAN**
#
# **“OPERATOR PADA PYTHON”**
#
# **Disusun Oleh :**
#
# **MUHAMMAD ABIYYU HAIDAR ARHAB**
#
# **2611533004**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Rifky Yuliandra**
#
# <br>
#
#  <img src="../image/images.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkat-Nya, sehingga penulis dapat menyelesaikan laporan praktikum ini yang telah dilaksanakan sebagai pertemuan ke-3 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pembahasan dan penerapan berbagai operasi dasar menggunakan bahasa Python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep operator aritmatika, perbandingan, logika, penugasan, keanggotaan, identitas, serta bitwise pada proyek nyata.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, September 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Bahasa pemrograman Python dikenal memiliki sintaksis yang sederhana namun kuat, salah satunya berkat ketersediaan berbagai jenis operator bawaan. Operator dalam Python merupakan simbol khusus yang digunakan untuk menjalankan operasi manipulasi data, baik berupa perhitungan aritmatika maupun pengujian kondisi logis. Pemahaman yang komprehensif mengenai karakteristik dan hierarki eksekusi operator sangat krusial bagi seorang programer untuk membangun algoritma yang efisien dan bebas dari kesalahan logika. Oleh karena itu, praktikum ini dilaksanakan untuk memberikan pemahaman mendalam mengenai implementasi berbagai jenis operator dalam menyelesaikan instruksi komputasional secara sistematis.
#
# ## 1.2 Tujuan
# 1. Mampu memahami berbagai jenis operator di dalam bahasa pemrograman Python.
# 2. Mampu menerapkan operasi matematis, bitwise, serta perbandingan logika dalam skrip kode.
# 3. Mampu menyelesaikan sebuah studi kasus terintegrasi menggunakan penggabungan beragam operasi logika dan kondis
# ## 1.3 Manfaat
# 1. Mahasiswa dapat mengoptimalkan penulisan kode program dengan menggunakan operator yang paling tepat dan efisien.
# 2. Mahasiswa dapat membangun logika algoritmik yang kuat dalam merancang suatu alur dari aplikasi atau sistem transaksi.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Secara fundamental, operator dalam bahasa pemrograman Python merupakan simbol atau karakter khusus yang mengompilasi satu atau lebih operan untuk menghasilkan suatu nilai baru. Penggunaan operator menjadi basis utama dalam memanipulasi data serta mengatur alur logika program. Python menyediakan beberapa kategori operator dengan karakteristik dan fungsi yang spesifik, yaitu sebagai berikut:
#
# 1.Operator Aritmatika:
# Berfungsi untuk mengeksekusi perhitungan matematis pada data numerik. Kategori ini mencakup penjumlahan (+), pengurangan (-), perkalian (*), pembagian konvensional (/), pembagian bulat (//), sisa pembagian atau modulus (%), dan perpangkatan (**).
#
# 2.Operator Relasional / Perbandingan:
# Digunakan untuk mengevaluasi hubungan antara dua entitas data yang menghasilkan luaran boolean (True atau False). Simbol yang digunakan meliputi sama dengan (==), tidak sama dengan (!=), lebih besar dari (>), kurang dari (<), serta lebih besar atau sama dengan (>=) dan kurang dari atau sama dengan (<=).
#
# 3.Operator Logika:
# Instrumen untuk mengombinasikan beberapa pernyataan kondisional. Terdiri dari and (menghasilkan True jika seluruh kondisi terpenuhi), or (menghasilkan True jika minimal satu kondisi terpenuhi), dan not (membalikkan status logika dasar).
#
# 4.Operator Penugasan (Assignment):
# Digunakan untuk mengalokasikan atau memperbarui nilai pada suatu variabel. Implementasinya bervariasi mulai dari penugasan dasar (=) hingga penugasan berbasis operasi aritmatika seperti +=, -=, *=, /=, %=, dan **=.
#
# 5.Operator Keanggotaan (Membership):
# Berfungsi untuk menguji keberadaan suatu elemen di dalam struktur data kolektif (seperti string, list, atau tuple) menggunakan sintaksis in dan not in.
#
# 6.Operator Identitas:
# Digunakan untuk memvalidasi apakah dua variabel merujuk pada objek yang sama di dalam memori komputer. Operasinya diwakili oleh is dan is not, yang secara prinsip berbeda dengan operator == karena tidak hanya memeriksa kesamaan nilai melainkan kesamaan alamat memori (reference).
#
# 7.Operator Bitwise:
# Beroperasi langsung pada representasi bilangan biner di tingkat bit. Jenis operasinya meliputi AND (&), OR (|), XOR (^), NOT (~), serta pergeseran posisi bit melalui left shift (<<) dan right shift (>>).

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "aritmatika_2611533004.py"

# %%
angka1_3004 = int(input("Input angka-1_3004: "))
angka2_3004 = int(input("Input angka-2_3004: "))

#Penjumlahan
hasil_3004= angka1_3004 + angka2_3004
print("\nOperator Penjumlahan",)
print("Hasil_3004 = ", hasil_3004)

#pengurangan
hasil_3004= angka1_3004 - angka2_3004
print("\nOperator Pengurangan",)
print("Hasil_3004 = ", hasil_3004)

#perkalian
hasil_3004= angka1_3004 * angka2_3004
print("\nOperator Perkalian",)
print("Hasil_3004 = ", hasil_3004)

#pembagian,pembagian bulat, dan sisa bagi
if angka2_3004 != 0:
    hasil_3004= angka1_3004 / angka2_3004
    print("\nOperator Pembagian",)
    print("Hasil_3004 = ", hasil_3004)

    hasil_3004= angka1_3004 // angka2_3004
    print("\nOperator Pembagian Bulat",)
    print("Hasil_3004 = ", hasil_3004)

    hasil_3004= angka1_3004 % angka2_3004
    print("\nOperator sisa bagi",)
    print("Hasil_3004 = ", hasil_3004)
else:
    print("Angka-2_3004 tidak boleh nol untuk operasi pembagian, pembagian bulat, dan sisa bagi.")  

#Pangkat
hasil_3004= angka1_3004 ** angka2_3004
print("\nOperator pangkat",)
print("Hasil_3004 = ", hasil_3004)
# Out:
# Operator Penjumlahan
# Hasil_3004 =  12
#
# Operator Pengurangan
# Hasil_3004 =  -2
#
# Operator Perkalian
# Hasil_3004 =  35
#
# Operator Pembagian
# Hasil_3004 =  0.7142857142857143
#
# Operator Pembagian Bulat
# Hasil_3004 =  0
#
# Operator sisa bagi
# Hasil_3004 =  5
#
# Operator pangkat
# Hasil_3004 =  78125

# %% [markdown]
# <div align="center">
# <img src="../image/Aritmatika.png" width="400"><br>
# <em>Gambar 2.1 : Output Program Aritmatika</em>
# </div>
#
# **Penjelasan :**
# Program di atas menerapkan pengoperasian matematis dasar dengan menerima dua input nilai dari pengguna yang langsung dikonversikan ke integer menggunakan fungsi `int(input())`. Khusus untuk pengoperasian pembagian, terdapat pengamanan selektif `if-else` agar program tidak mengalami pesan error, yang mewajibkan variabel pembagi angka2_1012 tidak bernilai 0.

# %% [markdown]
# ### 2.2.2 Program String "Assignment_2611533004"

# %%
angka1_3004 = int(input("Input angka-1_3004: "))
angka2_3004 = int(input("Input angka-2_3004: "))

print("\nNilai angka-1_3004 =", angka1_3004)
print("Nilai angka-2_3004 =", angka2_3004)  

#Assignment biasa
hasil_3004 = angka1_3004
print("\nAssignment biasa (=)",)
print("Hasil_3004 = ", hasil_3004)

#Asignment penjumlahan
hasil_3004 += angka2_3004
print("\nAssigment penjumlahan (+=)",)
print("Hasil_3004 = ", hasil_3004)

#Assignment pengurangan
hasil_3004 -= angka2_3004
print("\nAssigment pengurangan (-=)",)
print("Hasil_3004 = ", hasil_3004)

#Assignment perkalian
hasil_3004 *= angka1_3004
hasil_3004 *= angka2_3004
print("\nAssigment perkalian (*=)",)
print("Hasil_3004 = ", hasil_3004)

#Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_3004 !=0:
  hasil_3004= angka1_3004
  hasil_3004/= angka2_3004
  print("\nAssigment pembagian (/=)",)
  print("Hasil_3004 = ", hasil_3004)
  #operator tambahan
  hasil_3004= angka1_3004
  hasil_3004//= angka2_3004
  print("\nAssigment pembagian bulat (//=)",)
  print("Hasil_3004 = ", hasil_3004)
  hasil_3004= angka1_3004
  hasil_3004 %= angka2_3004
  print("\nAssigment sisa bagi (%=)",)
  print("Hasil_3004 = ", hasil_3004)
else:
  print("\nPembagian tidak dapat dilakukan .")  
  print("Angka kedua tidak boleh nol untuk operasi pembagian, pembagian bulat, dan sisa bagi.")

# Operator tambahan: assignment perpangkatan
hasil_3004= angka1_3004
hasil_3004 **= angka2_3004
print("\nAssignment perpanggkatan (**=)")
print("Hasil_3004 =" , hasil_3004)
# Out:
# Nilai angka-1_3004 = 5
# Nilai angka-2_3004 = 7
#
# Assignment biasa (=)
# Hasil_3004 =  5
#
# Assigment penjumlahan (+=)
# Hasil_3004 =  12
#
# Assigment pengurangan (-=)
# Hasil_3004 =  5
#
# Assigment perkalian (*=)
# Hasil_3004 =  175
#
# Assigment pembagian (/=)
# Hasil_3004 =  0.7142857142857143
#
# Assigment pembagian bulat (//=)
# Hasil_3004 =  0
#
# Assigment sisa bagi (%=)
# Hasil_3004 =  5
#
# Assignment perpanggkatan (**=)
# Hasil_3004 = 78125

# %% [markdown]
# <div align="center">
# <img src="../image/assignment.png" width="400"><br>
# <em>Gambar 2.2 : Output Program Assigment</em>
# </div>
#
# Penjelasan program driver di atas: ...
#
# Program menugaskan kembali nilai `hasil_3004` menggunakan assignment kombo seperti `+=`, `-=`, `*=`, `/=`, `//=`, `%=`, dan `**=`. Variabel penampung hasil harus selalu diinisialisasi atau disegarkan (refresh) setiap masuk baris perintah yang baru sehingga kalkulasi penambahan maupun perpangkatannya valid mengacu pada nilai orisinal dari variabel `angka1_3004`.

# %% [markdown]
# ### 2.2.3 Program Bitwise "bitwise_2611533004"

# %%
print("===============================")
print("3, OPERATOR BITWISE")
print("===============================")

angka1_3004=int(input("masukan angka bitwise-1: "))
angka2_3004=int(input("masukan angka bitwise-2: "))

print("\nAngka dalam bentuk biner dan desimal")
print("Angka 1 - Biner:", bin(angka1_3004), "- Desimal:", angka1_3004)
print("Angka 2 - Biner:", bin(angka2_3004), "- Desimal:", angka2_3004)

#Bitwise AND
hasil_3004= angka1_3004 & angka2_3004
print("\nOperator Bitwise AND (&)")
print(angka1_3004, "&", angka2_3004, "=", hasil_3004, "- Biner:", bin(hasil_3004))
print("Biner hasil (8 bit):", format(hasil_3004, '08b'))

#Bitwise OR
hasil_3004= angka1_3004 | angka2_3004
print("\nOperator Bitwise OR (|)")
print(angka1_3004, "|", angka2_3004, "=", hasil_3004,)
print("biner hasil =", bin(hasil_3004))
print("Biner hasil (8 bit):", format(hasil_3004, '08b'))

#Bitwise XOR
hasil_3004= angka1_3004 ^ angka2_3004   
print("\nOperator Bitwise XOR (^)")
print(angka1_3004, "^", angka2_3004, "=", hasil_3004,)
print("biner hasil =", bin(hasil_3004))
print("Biner hasil (8 bit):", format(hasil_3004, '08b'))

#bitwise NOT
hasil_3004= ~angka1_3004
print("\nOperator Bitwise NOT (~)")
print("~", angka1_3004, "=", hasil_3004,)
print("biner hasil =", bin(hasil_3004))
print("Biner hasil (8 bit):", format(hasil_3004, '08b'))

#bitwise left shift
jumlah_shift_3004 = int(input("\nMasukan jumlah pergeseran bit ke kiri: "))

hasil_3004= angka1_3004 << jumlah_shift_3004
print("\nOperator Bitwise Left Shift (<<)")
print(angka1_3004, "<<", jumlah_shift_3004, "=", hasil_3004,)
print("biner hasil =", bin(hasil_3004))
print("Biner hasil (8 bit):", format(hasil_3004, '08b'))

#bitwise right shift
hasil_3004= angka1_3004 >> jumlah_shift_3004
print("\nOperator Bitwise Right Shift (>>)")
print(angka1_3004, ">>", jumlah_shift_3004, "=", hasil_3004,)
print("biner hasil =", bin(hasil_3004))
print("Biner hasil (8 bit):", format(hasil_3004, '08b'))
# Out:
# ...
# 3, OPERATOR BITWISE
# ...
#
# Angka dalam bentuk biner dan desimal
# Angka 1 - Biner: 0b111 - Desimal: 7
# Angka 2 - Biner: 0b101 - Desimal: 5
#
# Operator Bitwise AND (&)
# 7 & 5 = 5 - Biner: 0b101
# Biner hasil (8 bit): 00000101
#
# Operator Bitwise OR (|)
# 7 | 5 = 7
# biner hasil = 0b111
# Biner hasil (8 bit): 00000111
#
# Operator Bitwise XOR (^)
# 7 ^ 5 = 2
# biner hasil = 0b10
# Biner hasil (8 bit): 00000010
#
# Operator Bitwise NOT (~)
# ~ 7 = -8
# biner hasil = -0b1000
# Biner hasil (8 bit): -0001000
#
# Operator Bitwise Left Shift (<<)
# 7 << 3 = 56
# biner hasil = 0b111000
# Biner hasil (8 bit): 00111000
#
# Operator Bitwise Right Shift (>>)
# 7 >> 3 = 0
# biner hasil = 0b0
# Biner hasil (8 bit): 00000000

# %% [markdown]
# <div align="center">
# <img src="../image/Bitwise.png" width="400"><br>
# <em>Gambar 2.3 : Output Program Bitwise</em>
# </div>
#
# Penjelasan program bitwise di atas:
#
# Program ini mengeksekusi operasi logika dasar berbasis bit seperti `AND`, `OR`, `XOR`, hingga invers `NOT` di mana setiap perhitungannya dikonversikan ke dalam format bilangan berbasis dua (biner) menggunakan instruksi `bin()` serta mencetak format kustom 8-bit `08b`. Pengguna juga diizinkan menyesuaikan pergeseran rentang bit secara bebas dengan input yang ditampung variabel `jumlah_geser_3004`.

# %% [markdown]
# ### 2.2.4 Program lainnya "Lainnya_2611533004"

# %%
print("===============================")    
print("1, OPERATOR KEANGGOTAAN")
print("===============================")

input_data_3004 =input("Masukan beberapa angka, pisahkan dengan koma:")

data_3004=[int(angka.strip()) for angka in input_data_3004.split(",")]

nilai_dicari = [int(input("Masukan angka yang dicari: "))]

#Operator keanggotaan in
hasil_3004 = nilai_dicari in data_3004
print("\nOperator keanggotaan IN")
print(nilai_dicari, "in", data_3004, "=", hasil_3004)

# Operator keanggotaan not in
hasil_3004 = nilai_dicari not in data_3004
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari, "not in", data_3004, "=", hasil_3004)   

print("===============================")
print("2, OPERATOR IDENTITAS")
print("===============================")

# Objek1_3004 menggunakan list dari input pengguna
objek1_3004 = data_3004 

# Objek1_3004 merujuk pada
objek2_3004 = objek1_3004

objek3_3004 = data_3004.copy()

print("objek1_3004 =" ,objek1_3004)
print("objek2_3004 =" ,objek2_3004)
print("objek3_3004 =" ,objek3_3004)

#Operator identitas is
hasil_3004 = objek1_3004 is objek2_3004
print("\nOperator identitas IS")
print("objek1_3004 is objek2_3004 =", hasil_3004)

#Operator identitas is not
hasil_3004 = objek1_3004 is not objek3_3004
print("\nOperator identitas IS NOT")
print("objek1_3004 is not objek3_3004 =", hasil_3004)

#Membandiingkan identitas dan nilai
print("\nMembandingkan identitas dan nilai")
print("objek1_3004 is objek3_3004 =", objek1_3004 is objek3_3004)
print("objek1_3004 == objek3_3004 =", objek1_3004 == objek3_3004)
# Out:
# ...
# 1, OPERATOR KEANGGOTAAN
# ...
#
# Operator keanggotaan IN
# [5] in [4, 5, 6] = False
#
# Operator keanggotaan NOT IN
# [5] not in [4, 5, 6] = True
# ...
# 2, OPERATOR IDENTITAS
# ...
# objek1_3004 = [4, 5, 6]
# objek2_3004 = [4, 5, 6]
# objek3_3004 = [4, 5, 6]
#
# Operator identitas IS
# objek1_3004 is objek2_3004 = True
#
# Operator identitas IS NOT
# objek1_3004 is not objek3_3004 = True
#
# Membandingkan identitas dan nilai
# objek1_3004 is objek3_3004 = False
# objek1_3004 == objek3_3004 = True

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="../image/Lainnya.png" width="400"><br>
# <em>Gambar 2.4 : Output Program Lainnya</em>
# </div>
#
# **Penjelasan :**
# Program mendemonstrasikan pemeriksan keanggotaan dengan mengecek apakah inputan tersimpan di dalam list (`in` dan `not in`) setelah string angka dilakukan metode pemisahan koma `.split(",")`. Pada tahapan kedua, program memperlihatkan perbedaan antara menginisialisasi rujukan ke objek yang sama `objek2_3004 = objek1_3004` dengan pembentukan salinan mandiri `data_3004.copy()`. Hasil `is` dan `is not` merepresentasikan perbandingan lokasi memori, bukan sekadar membandingkan kesetaraan nilai biasa.

# %% [markdown]
# ### 2.2.5 Program logika "logika_2611533004"

# %%
# Masukan nilai boolean
# Input tidak peka terhadap huruf besar dan kecil
a1_3004 = input("Masukan nilai boolean (True/False): ").strip().lower() == "true" 
a2_3004 = input("Masukan nilai boolean (True/False): ").strip().lower() == "true" 
# Menghapus spasi dan mengubah ke huruf kecil
print("\nA1_3004 =", a1_3004)
print("A2_3004 =", a2_3004)

#Kongjungsi bernilai True jika kedua operand bernilai True
hasil_3004 = a1_3004 and a2_3004
print("\nKongjungsi (AND):")
print("A1_3004 AND A2_3004 =", hasil_3004)  

#Disjungsi bernilai True jika salah satu operand bernilai True
hasil_3004 = a1_3004 or a2_3004
print("\nDisjungsi (OR):")
print("A1_3004 OR A2_3004 =", hasil_3004)

#Negasi a1_3004 membalikkan nilai a1
hasil_3004 = not a1_3004
print("\nNegasi A1_3004 (NOT):")
print("NOT A1_3004 =", hasil_3004)

#Negasi A2_3004 membalikan nilai a2
hasil_3004 = not a2_3004
print("\nNegasi A2_3004 (NOT):")
print("NOT A2_3004 =", hasil_3004)

#XOR: bernilai true jika kedua nilai berbeda
hasil_3004 = a1_3004 != a2_3004
print("\nDisjungsi Ekslusif (XOR)")
print("A1 XOR A2 =", hasil_3004)
# Out:
# A1_3004 = False
# A2_3004 = False
#
# Kongjungsi (AND):
# A1_3004 AND A2_3004 = False
#
# Disjungsi (OR):
# A1_3004 OR A2_3004 = False
#
# Negasi A1_3004 (NOT):
# NOT A1_3004 = True
#
# Negasi A2_3004 (NOT):
# NOT A2_3004 = True
#
# Disjungsi Ekslusif (XOR)
# A1 XOR A2 = False

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="..//image/Logika.png" width="400"><br>
# <em>Gambar 2.5 : Output Program Logika</em>
# </div>
#
# **Penjelasan :**
# Program membaca kondisi masukan berbasis huruf namun disanitasi sehingga bersifat absolut tidak case-sensitive melalui perpaduan instuksi pembersihan spasi `.strip()` dan `.lower()`. Nilai akhir akan diproses menggunakan logika konjungsi (`and`), disjungsi fleksibel (`or`), dan operan pembalikan arah (`not`) dengan hasil output boolean sejati.

# %% [markdown]
# ### 2.2.6 Program Perbandingan "perbandingan_2611533004"

# %%
angka1_3004 =int(input("Input angka-1_3004: "))
angka2_3004 =int(input("Input angka-2_3004: "))

#Lebih besar dari
hasil_3004= angka1_3004 > angka2_3004
print("\nOperator Lebih besar dari",)
print("angka 1 > angka 2 = ", hasil_3004)

#Lebih kecil dari
hasil_3004= angka1_3004 < angka2_3004
print("\nOperator Lebih kecil dari",)
print("angka 1 < angka 2 = ", hasil_3004)

# Lebih besar dari sama dengan
hasil_3004= angka1_3004 >= angka2_3004
print("\nOperator Lebih besar dari sama dengan",)
print("angka 1 >= angka 2 = ", hasil_3004)

# Lebih kecil dari sama dengan
hasil_3004= angka1_3004 <= angka2_3004
print("\nOperator Lebih kecil dari sama dengan",)
print("angka 1 <= angka 2 = ", hasil_3004)

#sama dengan
hasil_3004= angka1_3004 == angka2_3004
print("\nOperator sama dengan",)
print("angka 1 == angka 2 = ", hasil_3004)

#tidak sama dengan
hasil_3004= angka1_3004 != angka2_3004
print("\nOperator tidak sama dengan",)
print("angka 1 != angka 2 = ", hasil_3004)

#Tambahan: n perbandingan berantai dalam Python
hasil_3004 = 0 < angka1_3004 < 20
print("\nOperator perbandingan berantai",)
print("0 < angka 1 < 20 = ", hasil_3004)

hasil_3004 = 0 < angka1_3004 < 20 < angka2_3004
print("0 < angka 1 < 20 < angka 2 = ", hasil_3004)
# Out:
# Operator Lebih besar dari
# angka 1 > angka 2 =  True
#
# Operator Lebih kecil dari
# angka 1 < angka 2 =  False
#
# Operator Lebih besar dari sama dengan
# angka 1 >= angka 2 =  True
#
# Operator Lebih kecil dari sama dengan
# angka 1 <= angka 2 =  False
#
# Operator sama dengan
# angka 1 == angka 2 =  False
#
# Operator tidak sama dengan
# angka 1 != angka 2 =  True
#
# Operator perbandingan berantai
# 0 < angka 1 < 20 =  False
# 0 < angka 1 < 20 < angka 2 =  False

# %% [markdown]
# <div align="center">
# <img src="..//image/Perbandingan.png" width="400"><br>
# <em>Gambar 2.6 : Output Program Perbandingan</em>
# </div>
#
# **Penjelasan :**
# Selain melakukan uji parameter yang bersifat dasar seperti mendeteksi bilangan terbesar, terkecil, tidak sama dengan `!=`, dan persis sama `==`. Program ini juga menyematkan validasi berantai layaknya batasan rentang pada ilmu matematika konvensional `0 < x < 100` untuk membuktikan fungsionalitas sintaks di dalam Python sangat dinamis dan luwes dibaca.

# %% [markdown]
# # Tugas Praktikum
#
# **Soal :**
# Studi Kasus: Sistem Simulasi Transaksi dan Validasi Akses Toko
# Anda diminta untuk membuat sebuah program kasir sederhana yang digunakan untuk menghitung total transaksi pelanggan sekaligus melakukan pemeriksaan terhadap status pelanggan dan hak akses terhadap promo tertentu. Program menerima data transaksi dan informasi pelanggan, kemudian menggunakan berbagai jenis operator Python untuk menentukan total pembayaran, status diskon, kelayakan promo, serta hak akses pelanggan. Seluruh proses harus dibuat dalam satu alur program yang utuh

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Tugas3_2611533004.py"

# %%
# Tugas3_2611533004.py
# Sistem Simulasi Transaksi dan Validasi Akses Toko

print("=== SISTEM TRANSAKSI TOKO ===\n")

# Input Data Pelanggan
nama_3004 = input("Masukkan Nama Pelanggan : ")
status_3004 = input("Masukkan Status Pelanggan (member/nonmember) : ").lower()
total_belanja_3004 = int(input("Masukkan Total Belanja : "))
jumlah_barang_3004 = int(input("Masukkan Jumlah Barang : "))
kode_promo_input_3004 = input("Masukkan Kode Promo : ")

# Operator Keanggotaan
daftar_promo_3004 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]
promo_tersedia_3004 = kode_promo_input_3004 in daftar_promo_3004
promo_tidak_valid_3004 = kode_promo_input_3004 not in daftar_promo_3004

# Operator Perbandingan & Logika
syarat_belanja_3004 = total_belanja_3004 >= 200000
syarat_barang_3004 = jumlah_barang_3004 >= 3
is_member_3004 = status_3004 == "member"

# Logika Penggabungan (and)
dapat_diskon_3004 = is_member_3004 and syarat_belanja_3004
dapat_promo_3004 = promo_tersedia_3004 and syarat_barang_3004

# Operator Identitas
promo_ref_3004 = daftar_promo_3004
promo_copy_3004 = daftar_promo_3004.copy()
# Membuktikan identitas objek
is_same_object_3004 = promo_ref_3004 is daftar_promo_3004
is_diff_object_3004 = promo_copy_3004 is not daftar_promo_3004

# Operator Aritmatika & Penugasan
besaran_diskon_3004 = 0
if dapat_diskon_3004:
    besaran_diskon_3004 = total_belanja_3004 * 10 // 100  # Diskon 10% (Aritmatika Perkalian & Pembagian Bulat)

# Assignment
total_pembayaran_3004 = total_belanja_3004
total_pembayaran_3004 -= besaran_diskon_3004  # Augmented assignment pengurangan

# Aritmatika lanjutan
rata_rata_harga_3004 = total_belanja_3004 // jumlah_barang_3004
sisa_bagi_3004 = total_belanja_3004 % jumlah_barang_3004

# 6. Operator Bitwise
# 0001 (1) = Member | 0010 (2) = Belanja >= 200k | 0100 (4) = Barang >= 3 | 1000 (8) = Promo
status_code_3004 = 0
if is_member_3004: status_code_3004 |= 1
if syarat_belanja_3004: status_code_3004 |= 2
if syarat_barang_3004: status_code_3004 |= 4
if promo_tersedia_3004: status_code_3004 |= 8

cek_member_bitwise_3004 = status_code_3004 & 1
cek_promo_bitwise_3004 = status_code_3004 & 8

# Perbandingan Status (XOR) dan Shift
kode_referensi_3004 = 11  # 1011 Biner
hasil_xor_3004 = status_code_3004 ^ kode_referensi_3004
shift_kiri_3004 = status_code_3004 << 1

# === OUTPUT PROGRAM ===
print("\n=== DATA TRANSAKSI ===")
print(f"Nama Pelanggan       : {nama_3004}")
print(f"Status Pelanggan     : {status_3004}")
print(f"Total Belanja        : Rp{total_belanja_3004}")
print(f"Jumlah Barang        : {jumlah_barang_3004}")
print(f"Kode Promo           : {kode_promo_input_3004}")

print("\n=== HASIL VALIDASI ===")
print(f"Belanja >= Rp200000        : {syarat_belanja_3004}")
print(f"Jumlah Barang >= 3         : {syarat_barang_3004}")
print(f"Status Member              : {is_member_3004}")
print(f"Kode Promo Tersedia        : {promo_tersedia_3004}")
print(f"Mendapatkan Diskon         : {dapat_diskon_3004}")
print(f"Mendapatkan Promo          : {dapat_promo_3004}")

print("\n=== HASIL PERHITUNGAN ===")
print(f"Diskon                     : Rp{besaran_diskon_3004}")
print(f"Total Pembayaran           : Rp{total_pembayaran_3004}")
print(f"Rata-rata Harga Barang     : Rp{rata_rata_harga_3004}")
print(f"Sisa Bagi (Modulus)        : Rp{sisa_bagi_3004}")

print("\n=== HAK AKSES PELANGGAN ===")
print(f"Kode Hak Akses             : {format(status_code_3004, '04b')}")
print(f"Member Access              : {bool(cek_member_bitwise_3004)}")
print(f"Promo Access               : {bool(cek_promo_bitwise_3004)}")

print("\n=== OPERASI BITWISE ===")
print("=== Kode Status Transaksi ===")
print(f"Kode Biner   : {format(status_code_3004, '04b')}")
print(f"Kode Desimal : {status_code_3004}")

print("\n=== Pemeriksaan Status ===")
print("Cek Member")
print(f"{format(status_code_3004, '04b')} & 0001")
print(f"Hasil Biner   : {format(cek_member_bitwise_3004, '04b')}")
print(f"Hasil Desimal : {cek_member_bitwise_3004}")

print("\nCek Promo")
print(f"{format(status_code_3004, '04b')} & 1000")
print(f"Hasil Biner   : {format(cek_promo_bitwise_3004, '04b')}")
print(f"Hasil Desimal : {cek_promo_bitwise_3004}")

print("\n=== Perbandingan Status ===")
print(f"Kode Transaksi : {format(status_code_3004, '04b')}")
print(f"Kode Referensi : {format(kode_referensi_3004, '04b')}")
print(f"{format(status_code_3004, '04b')} ^ {format(kode_referensi_3004, '04b')}")
print(f"Hasil Biner   : {format(hasil_xor_3004, '04b')}")
print(f"Hasil Desimal : {hasil_xor_3004}")

print("\n=== Shift ===")
print(f"{format(status_code_3004, '04b')} << 1")
print(f"Hasil Biner   : {format(shift_kiri_3004, '05b')}")
print(f"Hasil Desimal : {shift_kiri_3004}")
print("\n=== SELESAI ===")

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="..//image/Tugas 3 part1.png" width="400"><br>
# <em>Gambar 2.3.1 : Output Tugas Praktikum</em>
# </div>
#
# <div align="center">
# <img src="..//image/TUGAS 3 part 2.png" width="400"><br>
# <em>Gambar 2.3.2 : Output Tugas Praktikum</em>
# </div>
# **Penjelasan :**
#
# === DATA TRANSAKSI ===
#
# **Output :**
#
# === DATA TRANSAKSI ===
# Blok ini mencetak kembali seluruh data mentah ("Muhammad Abiyyu Haidar Arhab", "member", Rp400000, 5, "HEMAT20") yang dimasukkan pada saat input. Tujuannya adalah untuk mengonfirmasi bahwa variabel telah menyimpan nilai dan tipe data yang benar sebelum diproses lebih lanjut.
#
# === HASIL VALIDASI ===
# Menampilkan pembuktian nilai boolean dari setiap operasi logika dan perbandingan. Seluruh output mencetak nilai True karena besaran transaksi dan status keanggotaan pelanggan berhasil memenuhi semua batas kriteria minimum yang ditetapkan dalam logika kode program.
#
# === HASIL PERHITUNGAN ===
# Menampilkan hasil matematis dari operator aritmatika. Diskon tercetak sebesar Rp40000 (10% dari 400.000), sehingga Total Pembayaran menyusut menjadi Rp360000. Rata-rata Harga Barang tercetak presisi di angka Rp80000 berkat operator pembagian bulat (//), dan Sisa Bagi (Modulus) adalah Rp0 karena 400.000 habis dibagi 5 tanpa sisa.
#
# === HAK AKSES PELANGGAN ===
# Menunjukkan representasi string biner dari variabel kode akses, yaitu 1111. Baris ini juga memverifikasi ulang bahwa hak akses member dan promo benar-benar aktif (True) berdasarkan ekstraksi bit tersebut.
#
# === OPERASI BITWISE ===
# Bagian ini membedah proses operasi level bit (biner) di balik layar:
# * **Kode Status Transaksi:** Mengonfirmasi bahwa biner 1111 memiliki padanan nilai desimal 15.
# * **Pemeriksaan Status:** Menunjukkan cara kerja Bitwise AND (&). Saat sandi 1111 disandingkan dengan masking 0001 (untuk mengecek member), hasilnya tetap 0001 (desimal 1). Begitu juga saat dicek dengan 1000 (untuk mengecek promo), hasilnya adalah 1000 (desimal 8). Ini membuktikan bit target dalam kondisi hidup/aktif.
# * **Perbandingan Status:** Menggunakan Bitwise XOR (^) untuk mencari perbedaan antara sandi 1111 dengan kode referensi 1011. Karena hanya bit ketiga dari kanan yang berbeda nilainya, output yang dihasilkan adalah 0100 atau berdesimal 4.
# * **Shift:** Menunjukkan hasil dari operator geser kiri (<< 1). Sandi 1111 digeser ke kiri sebanyak 1 posisi sehingga bergeser menjadi 11110, yang secara matematis melipatgandakan nilai desimalnya dari 15 menjadi 30.
#
# ---
#
# **Penjelasan :**
#
# **Tahap Input Data**
# Program dimulai dengan membaca lima nilai dari pengguna yang dimasukkan melalui keyboard. Berdasarkan eksekusi pada tangkapan layar, nilai yang diinput adalah nama pelanggan "Muhammad Abiyyu Haidar Arhab", status "member", total belanja "400000", jumlah barang "5", dan kode promo "HEMAT20". Data angka langsung dikonversi menjadi tipe data integer agar dapat dilakukan proses komputasi aritmatika.
#
# **Tahap Validasi Syarat (Logika, Perbandingan, dan Keanggotaan)**
# Program mengevaluasi kelayakan transaksi menggunakan operator perbandingan (>= dan ==) serta operator keanggotaan (in). Karena total belanja Rp400.000 lebih besar dari batas minimal Rp200.000, dan jumlah barang 5 melebihi syarat minimal 3, maka kondisi tersebut bernilai True. Selain itu, karena status pelanggan adalah "member" dan kode "HEMAT20" terdaftar dalam sistem promo, seluruh syarat dasar terpenuhi. Operator logika and kemudian memastikan pelanggan tersebut valid untuk mendapatkan diskon dan promo (True).
#
# **Tahap Perhitungan (Aritmatika & Penugasan)**
# Setelah syarat diskon divalidasi, program menghitung potongan sebesar 10% dari Rp400.000 menggunakan operator aritmatika perkalian (*) dan pembagian bulat (//), sehingga didapatkan angka Rp40.000. Menggunakan operator augmented assignment (-=), nilai total pembayaran dipotong langsung menjadi Rp360.000. Harga rata-rata barang juga dihitung menggunakan pembagian bulat menjadi Rp80.000, dengan hasil sisa bagi (modulus) Rp0.
#
# **Tahap Pengkodean Status Hak Akses (Bitwise)**
# Program merangkum keempat status pelanggan (member, batas belanja, batas barang, dan validitas promo) ke dalam satu sandi biner menggunakan Bitwise OR (|=). Karena pelanggan atas nama Muhammad Abiyyu Haidar Arhab memenuhi semua syarat, keempat bit diaktifkan, menghasilkan kode status biner 1111 yang setara dengan nilai desimal 15.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# 1. Berdasarkan hasil praktikum, dapat disimpulkan bahwa Python menyediakan berbagai jenis operator fundamental—seperti aritmatika, perbandingan, logika, penugasan, keanggotaan, identitas, dan bitwise—yang berfungsi secara efisien dalam memanipulasi variabel dan nilai data.
# 2. Penggabungan berbagai operator perbandingan dan logika dalam alur pemrograman terbukti mampu mempermudah penyusunan logika pengondisian yang kompleks dan dinamis, seperti yang diimplementasikan pada pembuatan sistem validasi syarat transaksi toko.
# 3. Operator bitwise (`&`, `|`, `^`, `<<`, `>>`) dapat dimanfaatkan sebagai metode pengkodean status hak akses pelanggan yang sangat efisien, di mana manipulasi data pada level biner mampu merangkum beberapa kondisi validasi ke dalam satu baris kode sandi matematika yang ringkas.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, "Built-in Expressions & Operators — Python 3.14 Documentation," Python Docs, 2026. [Online]. Tersedia: https://python.org. [Diakses: 19-Sep-2026].
#
# [2] Python Software Foundation, "Bitwise Operations on Integer Types — Python 3.14 Documentation," Python Docs, 2026. [Online]. Tersedia: https://python.org. [Diakses: 19-Sep-2026].
#
# [3] J. M. Zelle, Python Programming: An Introduction to Computer Science, 3rd ed. Oregon: Franklin, Beedle & Associates, 2016.
#
# [4] J. V. Guttag, Introduction to Computation and Programming Using Python: With Application to Computational Modeling and Understanding Data, 3rd ed. Cambridge: The MIT Press, 2021.
